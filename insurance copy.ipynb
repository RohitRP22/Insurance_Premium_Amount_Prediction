# %% [markdown]
# #### Premium amount analysis (OLS)

# %%
#importing Labirary
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
# %matplotlib inline
import seaborn as sns
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 #importing Labirary
# ----> 2 import numpy as np
#       3 import pandas as pd
#       4 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'numpy'

# %%
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv("Data.csv")

# %%
df.head()
# Out:
#     Age  Gender  Annual Income Marital Status  Number of Dependents  \
# 0  56.0    Male        99990.0        Married                   1.0
# 1  46.0    Male         2867.0         Single                   1.0
# 2  32.0  Female        30154.0       Divorced                   3.0
# 3  60.0  Female        48371.0       Divorced                   0.0
# 4  25.0  Female        54174.0       Divorced                   0.0
#
#   Education Level     Occupation  Health Score  Location    Policy Type  \
# 0        Master's            NaN     31.074627     Urban  Comprehensive
# 1      Bachelor's            NaN     50.271335     Urban  Comprehensive
# 2      Bachelor's            NaN     14.714909  Suburban  Comprehensive
# 3             PhD  Self-Employed     25.346926     Rural  Comprehensive
# 4     High School  Self-Employed      6.659499     Urban  Comprehensive
#
#    Previous Claims  Vehicle Age  Credit Score  Insurance Duration  \
# 0              NaN           13         320.0                   5
# 1              NaN            3         694.0                   4
# 2              2.0           16         652.0                   8
# 3              1.0           11         330.0                   7
# 4              NaN            9           NaN                   8
#
#    Premium Amount           Policy Start Date Customer Feedback  \
# 0           308.0  2022-12-10 15:21:39.078837              Poor
# 1           517.0  2023-01-31 15:21:39.078837              Good
# 2           849.0  2023-11-26 15:21:39.078837              Poor
# 3           927.0  2023-02-27 15:21:39.078837              Poor
# 4           303.0  2020-11-25 15:21:39.078837              Poor
#
#   Smoking Status Exercise Frequency Property Type
# 0            Yes              Daily         Condo
# 1            Yes            Monthly         House
# 2             No            Monthly         House
# 3             No             Rarely         Condo
# 4             No             Rarely         Condo

# %%
df.columns
# Out:
# Index(['Age', 'Gender', 'Annual Income', 'Marital Status',
#        'Number of Dependents', 'Education Level', 'Occupation', 'Health Score',
#        'Location', 'Policy Type', 'Previous Claims', 'Vehicle Age',
#        'Credit Score', 'Insurance Duration', 'Premium Amount',
#        'Policy Start Date', 'Customer Feedback', 'Smoking Status',
#        'Exercise Frequency', 'Property Type'],
#       dtype='object')

# %%
df.shape
# Out:
# (278860, 20)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 278860 entries, 0 to 278859
# Data columns (total 20 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   Age                   274175 non-null  float64
#  1   Gender                278860 non-null  object
#  2   Annual Income         264905 non-null  float64
#  3   Marital Status        273841 non-null  object
#  4   Number of Dependents  250974 non-null  float64
#  5   Education Level       278860 non-null  object
#  6   Occupation            197572 non-null  object
#  7   Health Score          268263 non-null  float64
#  8   Location              278860 non-null  object
#  9   Policy Type           278860 non-null  object
#  10  Previous Claims       197572 non-null  float64
#  11  Vehicle Age           278860 non-null  int64
#  12  Credit Score          250974 non-null  float64
#  13  Insurance Duration    278860 non-null  int64
#  14  Premium Amount        277019 non-null  float64
#  15  Policy Start Date     278860 non-null  object
#  16  Customer Feedback     260511 non-null  object
#  17  Smoking Status        278860 non-null  object
#  18  Exercise Frequency    278860 non-null  object
#  19  Property Type         278860 non-null  object
# dtypes: float64(7), int64(2), object(11)
# memory usage: 42.6+ MB

# %%
df.isnull().sum()
# Out:
# Age                      4685
# Gender                      0
# Annual Income           13955
# Marital Status           5019
# Number of Dependents    27886
# Education Level             0
# Occupation              81288
# Health Score            10597
# Location                    0
# Policy Type                 0
# Previous Claims         81288
# Vehicle Age                 0
# Credit Score            27886
# Insurance Duration          0
# Premium Amount           1841
# Policy Start Date           0
# Customer Feedback       18349
# Smoking Status              0
# Exercise Frequency          0
# Property Type               0
# dtype: int64

# %%
def null_percentage(df):
    percent_missing = df.isnull().sum() * 100 / len(df)
    return percent_missing

# %%
null_percentage(df)
# Out:
# Age                      1.680055
# Gender                   0.000000
# Annual Income            5.004303
# Marital Status           1.799828
# Number of Dependents    10.000000
# Education Level          0.000000
# Occupation              29.150111
# Health Score             3.800115
# Location                 0.000000
# Policy Type              0.000000
# Previous Claims         29.150111
# Vehicle Age              0.000000
# Credit Score            10.000000
# Insurance Duration       0.000000
# Premium Amount           0.660188
# Policy Start Date        0.000000
# Customer Feedback        6.580004
# Smoking Status           0.000000
# Exercise Frequency       0.000000
# Property Type            0.000000
# dtype: float64

# %%
# df['Previous Claims'] = df['Previous Claims'].fillna(0)

# %%
df.head()
# Out:
#     Age  Gender  Annual Income Marital Status  Number of Dependents  \
# 0  56.0    Male        99990.0        Married                   1.0
# 1  46.0    Male         2867.0         Single                   1.0
# 2  32.0  Female        30154.0       Divorced                   3.0
# 3  60.0  Female        48371.0       Divorced                   0.0
# 4  25.0  Female        54174.0       Divorced                   0.0
#
#   Education Level     Occupation  Health Score  Location    Policy Type  \
# 0        Master's            NaN     31.074627     Urban  Comprehensive
# 1      Bachelor's            NaN     50.271335     Urban  Comprehensive
# 2      Bachelor's            NaN     14.714909  Suburban  Comprehensive
# 3             PhD  Self-Employed     25.346926     Rural  Comprehensive
# 4     High School  Self-Employed      6.659499     Urban  Comprehensive
#
#    Previous Claims  Vehicle Age  Credit Score  Insurance Duration  \
# 0              NaN           13         320.0                   5
# 1              NaN            3         694.0                   4
# 2              2.0           16         652.0                   8
# 3              1.0           11         330.0                   7
# 4              NaN            9           NaN                   8
#
#    Premium Amount           Policy Start Date Customer Feedback  \
# 0           308.0  2022-12-10 15:21:39.078837              Poor
# 1           517.0  2023-01-31 15:21:39.078837              Good
# 2           849.0  2023-11-26 15:21:39.078837              Poor
# 3           927.0  2023-02-27 15:21:39.078837              Poor
# 4           303.0  2020-11-25 15:21:39.078837              Poor
#
#   Smoking Status Exercise Frequency Property Type
# 0            Yes              Daily         Condo
# 1            Yes            Monthly         House
# 2             No            Monthly         House
# 3             No             Rarely         Condo
# 4             No             Rarely         Condo

# %%
#df['Occupation'] = df['Occupation'].fillna('Unemployed')

# %%
df['Gender'] = df['Gender'].replace({'Male':1 , 'Female':0})
df['Smoking Status'] = df['Smoking Status'].replace({'Yes':1, 'No':0})

# %%
df.duplicated().sum()
# Out:
# 0

# %%
null_percentage(df)
# Out:
# Age                      1.680055
# Gender                   0.000000
# Annual Income            5.004303
# Marital Status           1.799828
# Number of Dependents    10.000000
# Education Level          0.000000
# Occupation              29.150111
# Health Score             3.800115
# Location                 0.000000
# Policy Type              0.000000
# Previous Claims         29.150111
# Vehicle Age              0.000000
# Credit Score            10.000000
# Insurance Duration       0.000000
# Premium Amount           0.660188
# Policy Start Date        0.000000
# Customer Feedback        6.580004
# Smoking Status           0.000000
# Exercise Frequency       0.000000
# Property Type            0.000000
# dtype: float64

# %%
df.dropna(inplace=True)

# %%
df.shape
# Out:
# (92985, 20)

# %%
df.isna().sum()
# Out:
# Age                     0
# Gender                  0
# Annual Income           0
# Marital Status          0
# Number of Dependents    0
# Education Level         0
# Occupation              0
# Health Score            0
# Location                0
# Policy Type             0
# Previous Claims         0
# Vehicle Age             0
# Credit Score            0
# Insurance Duration      0
# Premium Amount          0
# Policy Start Date       0
# Customer Feedback       0
# Smoking Status          0
# Exercise Frequency      0
# Property Type           0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 92985 entries, 3 to 278854
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Age                   92985 non-null  float64
#  1   Gender                92985 non-null  int64
#  2   Annual Income         92985 non-null  float64
#  3   Marital Status        92985 non-null  object
#  4   Number of Dependents  92985 non-null  float64
#  5   Education Level       92985 non-null  object
#  6   Occupation            92985 non-null  object
#  7   Health Score          92985 non-null  float64
#  8   Location              92985 non-null  object
#  9   Policy Type           92985 non-null  object
#  10  Previous Claims       92985 non-null  float64
#  11  Vehicle Age           92985 non-null  int64
#  12  Credit Score          92985 non-null  float64
#  13  Insurance Duration    92985 non-null  int64
#  14  Premium Amount        92985 non-null  float64
#  15  Policy Start Date     92985 non-null  object
#  16  Customer Feedback     92985 non-null  object
#  17  Smoking Status        92985 non-null  int64
#  18  Exercise Frequency    92985 non-null  object
#  19  Property Type         92985 non-null  object
# dtypes: float64(7), int64(4), object(9)
# memory usage: 14.9+ MB

# %%
df['Exercise Frequency'].head()
# Out:
# 3      Rarely
# 5       Daily
# 6     Monthly
# 8      Rarely
# 11     Rarely
# Name: Exercise Frequency, dtype: object

# %%
df.describe()
# Out:
#                 Age        Gender  Annual Income  Number of Dependents  \
# count  92985.000000  92985.000000   92985.000000          92985.000000
# mean      41.014121      0.500285   42098.392095              2.000635
# std       13.552250      0.500003   35484.380179              1.412383
# min       18.000000      0.000000       0.000000              0.000000
# 25%       29.000000      0.000000   13614.000000              1.000000
# 50%       41.000000      1.000000   32138.000000              2.000000
# 75%       53.000000      1.000000   62119.000000              3.000000
# max       64.000000      1.000000  149996.000000              4.000000
#
#        Health Score  Previous Claims   Vehicle Age  Credit Score  \
# count  92985.000000     92985.000000  92985.000000  92985.000000
# mean      28.584177         0.997720      9.488434    574.973544
# std       16.011769         1.000675      5.763703    158.820093
# min        0.116550         0.000000      0.000000    300.000000
# 25%       16.082971         0.000000      4.000000    438.000000
# 50%       26.448279         1.000000      9.000000    575.000000
# 75%       39.021673         2.000000     14.000000    713.000000
# max       93.876090         9.000000     19.000000    849.000000
#
#        Insurance Duration  Premium Amount  Smoking Status
# count        92985.000000    92985.000000    92985.000000
# mean             5.013206      969.799226        0.501113
# std              2.580619      912.589025        0.500001
# min              1.000000        0.000000        0.000000
# 25%              3.000000      288.000000        0.000000
# 50%              5.000000      691.000000        1.000000
# 75%              7.000000     1371.000000        1.000000
# max              9.000000     4999.000000        1.000000

# %%
df.head()
# Out:
#      Age  Gender  Annual Income Marital Status  Number of Dependents  \
# 3   60.0       0        48371.0       Divorced                   0.0
# 5   38.0       1        31769.0        Married                   1.0
# 6   56.0       0        26209.0         Single                   1.0
# 8   40.0       1        29471.0         Single                   4.0
# 11  41.0       0        36427.0         Single                   2.0
#
#    Education Level     Occupation  Health Score  Location    Policy Type  \
# 3              PhD  Self-Employed     25.346926     Rural  Comprehensive
# 5       Bachelor's       Employed     14.736611     Rural  Comprehensive
# 6         Master's       Employed     33.238300     Urban        Premium
# 8      High School     Unemployed     31.565248     Rural          Basic
# 11     High School  Self-Employed     13.264415  Suburban        Premium
#
#     Previous Claims  Vehicle Age  Credit Score  Insurance Duration  \
# 3               1.0           11         330.0                   7
# 5               1.0            9         521.0                   7
# 6               0.0           10         424.0                   5
# 8               1.0           14         796.0                   7
# 11              0.0           11         444.0                   9
#
#     Premium Amount           Policy Start Date Customer Feedback  \
# 3            927.0  2023-02-27 15:21:39.078837              Poor
# 5           4016.0  2020-09-16 15:21:39.078837              Poor
# 6            828.0  2021-03-29 15:21:39.078837           Average
# 8            975.0  2023-05-03 15:21:39.078837              Poor
# 11           207.0  2022-02-14 15:21:39.078837              Good
#
#     Smoking Status Exercise Frequency Property Type
# 3                0             Rarely         Condo
# 5                1              Daily         House
# 6                1            Monthly         Condo
# 8                0             Rarely         House
# 11               1             Rarely         House

# %%
df.drop(axis=1,columns=['Policy Start Date'], inplace=True)

# %%
df.head()
# Out:
#      Age  Gender  Annual Income Marital Status  Number of Dependents  \
# 3   60.0       0        48371.0       Divorced                   0.0
# 5   38.0       1        31769.0        Married                   1.0
# 6   56.0       0        26209.0         Single                   1.0
# 8   40.0       1        29471.0         Single                   4.0
# 11  41.0       0        36427.0         Single                   2.0
#
#    Education Level     Occupation  Health Score  Location    Policy Type  \
# 3              PhD  Self-Employed     25.346926     Rural  Comprehensive
# 5       Bachelor's       Employed     14.736611     Rural  Comprehensive
# 6         Master's       Employed     33.238300     Urban        Premium
# 8      High School     Unemployed     31.565248     Rural          Basic
# 11     High School  Self-Employed     13.264415  Suburban        Premium
#
#     Previous Claims  Vehicle Age  Credit Score  Insurance Duration  \
# 3               1.0           11         330.0                   7
# 5               1.0            9         521.0                   7
# 6               0.0           10         424.0                   5
# 8               1.0           14         796.0                   7
# 11              0.0           11         444.0                   9
#
#     Premium Amount Customer Feedback  Smoking Status Exercise Frequency  \
# 3            927.0              Poor               0             Rarely
# 5           4016.0              Poor               1              Daily
# 6            828.0           Average               1            Monthly
# 8            975.0              Poor               0             Rarely
# 11           207.0              Good               1             Rarely
#
#    Property Type
# 3          Condo
# 5          House
# 6          Condo
# 8          House
# 11         House

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 92985 entries, 3 to 278854
# Data columns (total 19 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Age                   92985 non-null  float64
#  1   Gender                92985 non-null  int64
#  2   Annual Income         92985 non-null  float64
#  3   Marital Status        92985 non-null  object
#  4   Number of Dependents  92985 non-null  float64
#  5   Education Level       92985 non-null  object
#  6   Occupation            92985 non-null  object
#  7   Health Score          92985 non-null  float64
#  8   Location              92985 non-null  object
#  9   Policy Type           92985 non-null  object
#  10  Previous Claims       92985 non-null  float64
#  11  Vehicle Age           92985 non-null  int64
#  12  Credit Score          92985 non-null  float64
#  13  Insurance Duration    92985 non-null  int64
#  14  Premium Amount        92985 non-null  float64
#  15  Customer Feedback     92985 non-null  object
#  16  Smoking Status        92985 non-null  int64
#  17  Exercise Frequency    92985 non-null  object
#  18  Property Type         92985 non-null  object
# dtypes: float64(7), int64(4), object(8)
# memory usage: 14.2+ MB

# %%
# float_columns = df.select_dtypes(include='float').columns 
# float_columns = df.dtypes[df.dtypes == "float64"].index
# int_index = df.dtypes[df.dtypes == 'int64'].index
# print(float_columns,int_index)

numerical_cols = df.select_dtypes(include=['number']).columns

# %% [markdown]
# ### Preprocessing

# %%
for i in numerical_cols:
    plt.hist(df[str(i)], bins=20)
    plt.xlabel(str(i))
    plt.ylabel('Frequency')
    plt.title('Histogram of '+ str(i))
    plt.show()

# %%
for i in numerical_cols:
    plt.boxplot(df[str(i)] )
    plt.xlabel(str(i))
    plt.ylabel('Frequency')
    plt.title('Boxplot')
    plt.show()

# %%
Q3_PA = df['Premium Amount'].quantile(0.75) 
Q1_PA = df['Premium Amount'].quantile(0.25) 
IQR_PA = Q3_PA-Q1_PA
print(IQR_PA)
# Out:
# 1083.0

# %%
lower_bound = Q1_PA - 1.5 * IQR_PA
upper_bound = Q3_PA + 1.5 * IQR_PA
df = df.loc[(df['Premium Amount'] >= lower_bound) & (df['Premium Amount'] <= upper_bound)]

# %%
Q3_AI = df['Annual Income'].quantile(0.75) 
Q1_AI = df['Annual Income'].quantile(0.25) 
IQR_AI = Q3_AI-Q1_AI
lower_bound = Q1_AI - 1.5 * IQR_AI
upper_bound = Q3_AI + 1.5 * IQR_AI

# %%
df = df.loc[(df['Annual Income'] >= lower_bound) & (df['Annual Income'] <= upper_bound)]

# %%
Q3_HS = df['Health Score'].quantile(0.75) 
Q1_HS = df['Health Score'].quantile(0.25) 
IQR_HS = Q3_HS-Q1_HS
lower_bound_HS = Q1_HS - 1.5 * IQR_HS
upper_bound_HS = Q3_HS + 1.5 * IQR_HS

# %%
df = df.loc[(df['Health Score'] >= lower_bound_HS) & (df['Health Score'] <= upper_bound_HS)]

# %%
df.shape
# Out:
# (86700, 19)

# %%
for i in numerical_cols:
    plt.hist(df[str(i)], bins=20)
    plt.xlabel(str(i))
    plt.ylabel('Frequency')
    plt.title('Histogram of '+ str(i))
    plt.show()

# %% [markdown]
# ### The Inverse Transform Method
# - The most common and theoretically sound way is to use the inverse CDF (quantile function) of the normal distribution.
#
# Here’s why:
#
# If 𝑋 ∼ 𝑈 (0 , 1) X∼U(0,1) (uniform between 0 and 1),
# then, 𝑌 = 𝐹^-1(𝑋)
# Y=F^-1(X) will be distributed according to the distribution with CDF F.
#
# For a normal distribution, F^-1 is the inverse normal CDF, also called the probit function.

# %%
from scipy.stats import norm

# %%
def uniTOnorm(data):
    X_scaled = (data - data.min()) / (data.max() - data.min())
    X_scaled = np.clip(X_scaled, 1e-10, 1 - 1e-10)
    normal = norm.ppf(X_scaled)
    
    return normal

# %%
# Credit Score, Age, Vehicle Age
uniform_cols = ['Credit Score', 'Age', 'Vehicle Age']

# Apply the function to a specific list of columns
df[uniform_cols] = df[uniform_cols].apply(uniTOnorm)

# %% [markdown]
# ### Skewed Data
#
# -it seems that Premium Amount is right-skewed (positively skewed)
#
# #### Good transformation for left skew
# General rule:
# - For right skew: log(x), sqrt(x), or 1/x work well.
# - For left skew: First reflect the data, then apply a right-skew fix.
#
# #### The reflection trick
# Steps:
# - Apply a right-skew fix:
# Try log(), sqrt(), or Box-Cox.

# %%
from scipy.stats import boxcox

# %%
df[df['Premium Amount'] <= 0].value_counts().sum()
# Out:
# 90

# %%
new_df = df[df['Premium Amount'] > 0]

# %%
# # 1. Reflect
# premium_reflected = df['Premium Amount'].max() + 1 - df['Premium Amount']

# # 2a. Log transform
premium_transformed = np.log(new_df['Premium Amount'])

# OR 2b. Box-Cox (automatically finds best power)
# Box-Cox needs positive data, so reflection works well
premium_bc, lmbda = boxcox(new_df['Premium Amount'])

# %%
print(premium_bc, lmbda)
# Out:
# [28.09156344 26.89829132 28.64030577 ... 26.83561182 26.53124211
#  21.50122026] 0.34795005419292796

# %%
plt.hist(premium_transformed, bins=20)
plt.xlabel('premium_transformed')
plt.ylabel('Frequency')
plt.title('Histogram of premium_transformed')
plt.show()


plt.hist(premium_bc, bins=20)
plt.xlabel('premium_bc')
plt.ylabel('Frequency')
plt.title('Histogram of premium_bc')
plt.show()

# %%
new_df['Premium Amount'] = premium_bc
# Out:
# C:\Users\ROHIT\AppData\Local\Temp\ipykernel_32240\1552375565.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['Premium Amount'] = premium_bc

# %%
new_df[new_df['Annual Income'] <= 0].value_counts().sum()
# Out:
# 3

# %%
new_df = new_df[new_df['Annual Income'] > 0]

# %%
premium_bc, lmbda = boxcox(new_df['Annual Income'])

# %%
plt.hist(premium_bc, bins=20)
plt.xlabel('premium_bc')
plt.ylabel('Frequency')
plt.title('Histogram of premium_bc')
plt.show()

# %%
new_df['Annual Income'] = premium_bc

# %%
for i in numerical_cols:
    plt.hist(new_df[str(i)], bins=20)
    plt.xlabel(str(i))
    plt.ylabel('Frequency')
    plt.title('Histogram of '+ str(i))
    plt.show()

# %%
#df = df[df['Premium Amount'] < (Q3+1.5*IQR_PA)]

# %%
sns.pairplot(new_df)

# %%
from scipy.stats import zscore
#numerical_cols = df.select_dtypes(include=['number']).columns

# %%
numerical_cols =list(numerical_cols)

# %%
numerical_cols.remove('Gender')
numerical_cols.remove('Smoking Status')
# numerical_cols.remove('Premium Amount')

# %%
numerical_cols
# Out:
# ['Age',
#  'Annual Income',
#  'Number of Dependents',
#  'Health Score',
#  'Previous Claims',
#  'Vehicle Age',
#  'Credit Score',
#  'Insurance Duration',
#  'Premium Amount']

# %%
df = new_df.copy()

# %%
df.head()
# Out:
#          Age  Gender  Annual Income Marital Status  Number of Dependents  \
# 3   1.359737       0     135.148098       Divorced                   0.0
# 6   0.938814       0     107.663842         Single                   1.0
# 8  -0.054519       1     112.463306         Single                   4.0
# 11  0.000000       0     121.668258         Single                   2.0
# 17 -2.019086       1      68.386845       Divorced                   0.0
#
#    Education Level     Occupation  Health Score  Location    Policy Type  \
# 3              PhD  Self-Employed     25.346926     Rural  Comprehensive
# 6         Master's       Employed     33.238300     Urban        Premium
# 8      High School     Unemployed     31.565248     Rural          Basic
# 11     High School  Self-Employed     13.264415  Suburban        Premium
# 17             PhD  Self-Employed     34.111462     Urban  Comprehensive
#
#     Previous Claims  Vehicle Age  Credit Score  Insurance Duration  \
# 3               1.0     0.199201     -1.601394                   7
# 6               0.0     0.066012     -0.752533                   5
# 8               1.0     0.633640      1.301526                   7
# 11              0.0     0.199201     -0.636286                   9
# 17              0.0     6.361341     -0.614081                   1
#
#     Premium Amount Customer Feedback  Smoking Status Exercise Frequency  \
# 3        28.091563              Poor               0             Rarely
# 6        26.898291           Average               1            Monthly
# 8        28.640306              Poor               0             Rarely
# 11       15.505161              Good               1             Rarely
# 17        0.000000              Poor               0             Rarely
#
#    Property Type
# 3          Condo
# 6          Condo
# 8          House
# 11         House
# 17         House

# %%
df[numerical_cols] = df[numerical_cols].apply(zscore)

# %%
#number of Unique values in columns
unique_values = df['Policy Type'].unique()
print(unique_values)
# Out:
# ['Comprehensive' 'Premium' 'Basic']

# %%
from sklearn.preprocessing import OrdinalEncoder
#Ordinal Data 
order = [['Basic','Comprehensive','Premium']]
#label encoder
encoder = OrdinalEncoder(categories=order)
df['Policy Type encoded'] = encoder.fit_transform(df[['Policy Type']]) + 1 # Add 1 to start from 1

# %%
df.drop(columns=['Policy Type'], inplace=True)

# %%
df.head()
# Out:
#          Age  Gender  Annual Income Marital Status  Number of Dependents  \
# 3   0.849527       0       0.498417       Divorced             -1.414918
# 6   0.585831       0      -0.158102         Single             -0.706985
# 8  -0.036464       1      -0.043457         Single              1.416815
# 11 -0.002310       0       0.176423         Single              0.000948
# 17 -1.267210       1      -1.096315       Divorced             -1.414918
#
#    Education Level     Occupation  Health Score  Location  Previous Claims  \
# 3              PhD  Self-Employed     -0.187818     Rural         0.002598
# 6         Master's       Employed      0.320027     Urban        -0.997601
# 8      High School     Unemployed      0.212359     Rural         0.002598
# 11     High School  Self-Employed     -0.965383  Suburban        -0.997601
# 17             PhD  Self-Employed      0.376219     Urban        -0.997601
#
#     Vehicle Age  Credit Score  Insurance Duration  Premium Amount  \
# 3      0.091837     -1.517253            0.771954        0.395332
# 6      0.030277     -0.714421           -0.002831        0.269934
# 8      0.292633      1.228260            0.771954        0.452997
# 11     0.091837     -0.604477            1.546740       -0.927335
# 17     2.939953     -0.583475           -1.552403       -2.556724
#
#    Customer Feedback  Smoking Status Exercise Frequency Property Type  \
# 3               Poor               0             Rarely         Condo
# 6            Average               1            Monthly         Condo
# 8               Poor               0             Rarely         House
# 11              Good               1             Rarely         House
# 17              Poor               0             Rarely         House
#
#     Policy Type encoded
# 3                   2.0
# 6                   3.0
# 8                   1.0
# 11                  3.0
# 17                  2.0

# %%
#categorical data
categorical_cols = df.select_dtypes(include=['object']).columns

df = pd.get_dummies(df, columns=categorical_cols, drop_first=True)

# %%
df.head()
# Out:
#          Age  Gender  Annual Income  Number of Dependents  Health Score  \
# 3   0.849527       0       0.498417             -1.414918     -0.187818
# 6   0.585831       0      -0.158102             -0.706985      0.320027
# 8  -0.036464       1      -0.043457              1.416815      0.212359
# 11 -0.002310       0       0.176423              0.000948     -0.965383
# 17 -1.267210       1      -1.096315             -1.414918      0.376219
#
#     Previous Claims  Vehicle Age  Credit Score  Insurance Duration  \
# 3          0.002598     0.091837     -1.517253            0.771954
# 6         -0.997601     0.030277     -0.714421           -0.002831
# 8          0.002598     0.292633      1.228260            0.771954
# 11        -0.997601     0.091837     -0.604477            1.546740
# 17        -0.997601     2.939953     -0.583475           -1.552403
#
#     Premium Amount  Smoking Status  Policy Type encoded  \
# 3         0.395332               0                  2.0
# 6         0.269934               1                  3.0
# 8         0.452997               0                  1.0
# 11       -0.927335               1                  3.0
# 17       -2.556724               0                  2.0
#
#     Marital Status_Married  Marital Status_Single  \
# 3                        0                      0
# 6                        0                      1
# 8                        0                      1
# 11                       0                      1
# 17                       0                      0
#
#     Education Level_High School  Education Level_Master's  \
# 3                             0                         0
# 6                             0                         1
# 8                             1                         0
# 11                            1                         0
# 17                            0                         0
#
#     Education Level_PhD  Occupation_Self-Employed  Occupation_Unemployed  \
# 3                     1                         1                      0
# 6                     0                         0                      0
# 8                     0                         0                      1
# 11                    0                         1                      0
# 17                    1                         1                      0
#
#     Location_Suburban  Location_Urban  Customer Feedback_Good  \
# 3                   0               0                       0
# 6                   0               1                       0
# 8                   0               0                       0
# 11                  1               0                       1
# 17                  0               1                       0
#
#     Customer Feedback_Poor  Exercise Frequency_Monthly  \
# 3                        1                           0
# 6                        0                           1
# 8                        1                           0
# 11                       0                           0
# 17                       1                           0
#
#     Exercise Frequency_Rarely  Exercise Frequency_Weekly  Property Type_Condo  \
# 3                           1                          0                    1
# 6                           0                          0                    1
# 8                           1                          0                    0
# 11                          1                          0                    0
# 17                          1                          0                    0
#
#     Property Type_House
# 3                     0
# 6                     0
# 8                     1
# 11                    1
# 17                    1

# %%
corr = df.corr()
mask = np.zeros_like(corr)
mask[np.triu_indices_from(mask)] = True
with sns.axes_style("white"):
    f, ax = plt.subplots(figsize=(15, 15))
    ax = sns.heatmap(corr,mask=mask,square=True,linewidths=.8,cmap="YlGnBu")

# %%
df.to_csv('final_data.csv', index=False)

# %%
x = df.drop(columns=['Premium Amount']) 
y = df['Premium Amount']

# %% [markdown]
# ### Modelling

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, x_test, Y_Train, y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
print(len(X_train),len(Y_Train),len(x_test),len(y_test))
# Out:
# 69285 69285 17322 17322

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(X_train,Y_Train)
# Out:
# LinearRegression()

# %%
model.predict(x_test)
# Out:
# array([ 0.03112814, -0.02164503,  0.00013208, ...,  0.00995683,
#         0.01085671,  0.01856992])

# %%
print(y_test)
# Out:
# 183763    1.332080
# 26320     0.827934
# 8356     -0.312615
# 9159     -1.664437
# 253131    0.748020
#             ...
# 214738   -0.322321
# 24289    -0.158970
# 242822    1.234951
# 135375   -0.855215
# 93828    -0.686924
# Name: Premium Amount, Length: 17322, dtype: float64

# %%
model.score(x_test,y_test)
# Out:
# -0.0003825630169924654

# %%
from sklearn.model_selection import RandomizedSearchCV
from sklearn.linear_model import Lasso

param_dist = {'alpha': [0.1, 1.0, 10.0, 100.0]}
lasso = Lasso()
random_search = RandomizedSearchCV(lasso, param_dist, n_iter=10, cv=5)
random_search.fit(X_train, Y_Train)
# Out:
# c:\Users\ROHIT\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:292: UserWarning: The total space of parameters 4 is smaller than n_iter=10. Running 4 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# RandomizedSearchCV(cv=5, estimator=Lasso(),
#                    param_distributions={'alpha': [0.1, 1.0, 10.0, 100.0]})

# %%
print(random_search.score(x_test, y_test))
print("Best parameters found: ", random_search.best_params_)
# Out:
# -4.9283891988993744e-05
# Best parameters found:  {'alpha': 0.1}

# %%
from sklearn.linear_model import Ridge
ridge = Ridge()
param_dist_ridge = {'alpha': [0.1, 1.0, 10.0, 100.0]}
random_search_ridge = RandomizedSearchCV(ridge, param_dist_ridge, n_iter=10, cv=5)

# %%
best_ridge = random_search_ridge
best_ridge.fit(X_train, Y_Train)
# Out:
# c:\Users\ROHIT\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:292: UserWarning: The total space of parameters 4 is smaller than n_iter=10. Running 4 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# RandomizedSearchCV(cv=5, estimator=Ridge(),
#                    param_distributions={'alpha': [0.1, 1.0, 10.0, 100.0]})

# %%
best_ridge.score(x_test, y_test)
# Out:
# -0.00037194531558459865

# %%
#Grid Search for Ridge Regression
from sklearn.model_selection import GridSearchCV
ridge = Ridge()
param_grid = {'alpha': [0.1, 1.0, 10.0, 100.0]}
grid_search = GridSearchCV(ridge, param_grid, cv=5)
grid_search.fit(X_train, Y_Train)
print("Best parameters found: ", grid_search.best_params_)
print("Best score: ", grid_search.best_score_)
# Out:
# Best parameters found:  {'alpha': 100.0}
# Best score:  -0.00027706006544270245

# %%
# grid search for Lasso Regression
lasso = Lasso()
param_grid_lasso = {'alpha': [0.1, 1.0, 10.0, 100.0]}
grid_search_lasso = GridSearchCV(lasso, param_grid_lasso, cv=5)
grid_search_lasso.fit(X_train, Y_Train)
print("Best parameters for Lasso found: ", grid_search_lasso.best_params_)
print("Best score for Lasso: ", grid_search_lasso.best_score_)
# Out:
# Best parameters for Lasso found:  {'alpha': 0.1}
# Best score for Lasso:  -6.0291060202377625e-05

# %% [markdown]
# ## XGBoost

# %%
import xgboost as xgb

# %%
xgb_model = xgb.XGBRegressor(objective='reg:squarederror', n_estimators=1000, learning_rate=0.1, max_depth=5)

# %%
xgb_model.fit(X_train, Y_Train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.1, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=5, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=1000, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=None, ...)

# %%
y_pred =xgb_model.predict(x_test)

# %%
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(y_test, y_pred)
print("Mean Squared Error:", mse)
# Out:
# Mean Squared Error: 1.02978882541568

# %%
from sklearn.metrics import r2_score
r2 = r2_score(y_test, y_pred)
print("R-squared:", r2)
# Out:
# R-squared: -0.030811561450475144

# %%
# Neural Network using pytorch
import torch
import torch.nn as nn
import torch.optim as optim
import torch.utils.data as data

class InsuranceNN(nn.Module):
    def __init__(self, input_size):
        super(InsuranceNN, self).__init__()
        self.fc1 = nn.Linear(input_size, 64)
        self.fc2 = nn.Linear(64, 32)
        self.fc3 = nn.Linear(32, 1)
        self.relu = nn.ReLU()
        self.dropout = nn.Dropout(0.2)

    def forward(self, x):
        x = self.fc1(x)
        x = self.relu(x)
        x = self.dropout(x)
        x = self.fc2(x)
        x = self.relu(x)
        x = self.dropout(x)
        x = self.fc3(x)
        return x
    
# Convert DataFrame to PyTorch tensors
X_train_tensor = torch.tensor(X_train.values, dtype=torch.float32)
Y_train_tensor = torch.tensor(Y_Train.values, dtype=torch.float32).view(-1, 1)
# Create DataLoader
train_dataset = data.TensorDataset(X_train_tensor, Y_train_tensor)
train_loader = data.DataLoader(train_dataset, batch_size=32, shuffle=True)
# Initialize the model, loss function, and optimizer
input_size = X_train.shape[1]
model_nn = InsuranceNN(input_size)
criterion = nn.MSELoss()
optimizer = optim.Adam(model_nn.parameters(), lr=0.001)
# Training the model
num_epochs = 100
for epoch in range(num_epochs):
    for inputs, targets in train_loader:
        optimizer.zero_grad()
        outputs = model_nn(inputs)
        loss = criterion(outputs, targets)
        loss.backward()
        optimizer.step()
    if (epoch+1) % 10 == 0:
        print(f'Epoch [{epoch+1}/{num_epochs}], Loss: {loss.item():.4f}')
# Evaluate the model
model_nn.eval()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [95], in <cell line: 2>()
#       1 # Neural Network using pytorch
# ----> 2 import torch
#       3 import torch.nn as nn
#       4 import torch.optim as optim
#
# ModuleNotFoundError: No module named 'torch'
